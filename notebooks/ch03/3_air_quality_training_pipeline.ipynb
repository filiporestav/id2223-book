# %% [markdown]
# # <span style="font-width:bold; font-size: 3rem; color:#333;">Training Pipeline</span>
#
# ## 🗒️ This notebook is divided into the following sections:
#
# 1. Select features for the model and create a Feature View with the selected features
# 2. Create training data using the feature view
# 3. Train model
# 4. Evaluate model performance
# 5. Save model to model registry

# %% [markdown]
# ### <span style='color:#ff5f27'> 📝 Imports

# %%
import os
from datetime import datetime, timedelta
import pandas as pd
import matplotlib.pyplot as plt
from xgboost import XGBRegressor
from xgboost import plot_importance
from sklearn.metrics import mean_squared_error, r2_score
import hopsworks
from functions import util
import json

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## <span style="color:#ff5f27;"> 📡 Connect to Hopsworks Feature Store </span>

# %%
# If you haven't set the env variable 'HOPSWORKS_API_KEY', then uncomment the next line and enter your API key
os.environ["HOPSWORKS_API_KEY"] = "2ZoLYydQfIz5VW5b.D5B2X2LLCmJsysb4n78mTmGgEAWzlLfrgRKcCLJXlE4iJZ9Mqhm1GhsG60PJQxls"

project = hopsworks.login()
fs = project.get_feature_store() 

secrets = util.secrets_api(project.name)
location_str = secrets.get_secret("SENSOR_LOCATION_JSON").value
location = json.loads(location_str)
country=location['country']
city=location['city']
street=location['street']
# Out:
# Connection closed.
# Connected. Call `.close()` to terminate connection gracefully.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1158296
# Connected. Call `.close()` to terminate connection gracefully.
# Connected. Call `.close()` to terminate connection gracefully.

# %%
# Retrieve feature groups
air_quality_fg = fs.get_feature_group(
    name='air_quality',
    version=1,
)
weather_fg = fs.get_feature_group(
    name='weather',
    version=1,
)

# %% [markdown]
# ---
#
# ## <span style="color:#ff5f27;"> 🖍 Feature View Creation and Retrieving </span>

# %%
# Select features for training data.
selected_features = air_quality_fg.select(['pm25', 'pm25_lag_1', 'pm25_lag_2', 'pm25_lag_3']).join(weather_fg.select_all(), on=['city'])

selected_features.show(10)
# Out:
# ---------------------------------------------------------------------------
# FeatureStoreException                     Traceback (most recent call last)
# File ~/id2223-book/venv/lib/python3.11/site-packages/hsfs/constructor/query.py:742, in Query.__getattr__(self, name)
#     741 try:
# --> 742     return self.__getitem__(name)
#     743 except FeatureStoreException:
#
# File ~/id2223-book/venv/lib/python3.11/site-packages/hsfs/constructor/query.py:752, in Query.__getitem__(self, name)
#     748     raise TypeError(
#     749         f"Expected type `str`, got `{type(name)}`. "
#     750         "Features are accessible by name."
#     751     )
# --> 752 return self.get_feature(name)
#
# File ~/id2223-book/venv/lib/python3.11/site-packages/hsfs/constructor/query.py:738, in Query.get_feature(self, feature_name)
#     729 """
#     730 Get a feature by name.
#     731
#    (...)
#     736     `Feature`. Feature object.
#     737 """
# --> 738 return self._get_feature_by_name(feature_name)[0]
#
# File ~/id2223-book/venv/lib/python3.11/site-packages/hsfs/constructor/query.py:671, in Query._get_feature_by_name(self, feature_name)
#     670 if feature_name not in query_features:
# --> 671     raise FeatureStoreException(
#     672         Query.ERROR_MESSAGE_FEATURE_NOT_FOUND.format(feature_name)
#     673     )
#     675 # return (feature, prefix, fg) tuple, if only one match was found
#
# FeatureStoreException: Feature name 'schema' could not found be found in query.
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 3
#       1 # Select features for training data.
#       2 selected_features = air_quality_fg.select(['pm25', 'pm25_lag_1', 'pm25_lag_2', 'pm25_lag_3']).join(weather_fg.select_all(), on=['city'])
# ----> 3 print("Selected features:", selected_features.schema)
#       4 selected_features.show(10)
#
# File ~/id2223-book/venv/lib/python3.11/site-packages/hsfs/constructor/query.py:744, in Query.__getattr__(self, name)
#     742     return self.__getitem__(name)
#     743 except FeatureStoreException:
# --> 744     raise AttributeError(f"'Query' object has no attribute '{name}'. ")
#
# AttributeError: 'Query' object has no attribute 'schema'.

# %% [markdown]
# ### Feature Views
#
# `Feature Views` are selections of features from different **Feature Groups** that make up the input and output API (or schema) for a model. A **Feature Views** can create **Training Data** and also be used in Inference to retrieve inference data.
#
# The Feature Views allows a schema in form of a query with filters, defining a model target feature/label and additional transformation functions (declarative feature encoding).
#
# In order to create Feature View we can use `FeatureStore.get_or_create_feature_view()` method.
#
# You can specify the following parameters:
#
# - `name` - name of a feature group.
#
# - `version` - version of a feature group.
#
# - `labels`- our target variable.
#
# - `transformation_functions` - declarative feature encoding (not used here)
#
# - `query` - selected features/labels for the model

# %%
feature_view = fs.get_or_create_feature_view(
    name='air_quality_fv',
    description="weather features with air quality as the target",
    version=1,
    labels=['pm25'],
    query=selected_features,
)
# Out:
# Feature view created successfully, explore it at
# https://c.app.hopsworks.ai:443/p/1158296/fs/1148999/fv/air_quality_fv/version/1

# %% [markdown]
# ## <span style="color:#ff5f27;">🪝 Split the training data into train/test data sets </span>
#
# We use a time-series split here, with training data before this date `start_date_test_data` and test data after this date

# %%
today = datetime.now()
start_date_test_data = today - timedelta(days=60) # around 1 month of data
start_date_test_data = start_date_test_data.strftime("%Y-%m-%d")
# Convert string to datetime object
test_start = datetime.strptime(start_date_test_data, "%Y-%m-%d")

# %%
X_train, X_test, y_train, y_test = feature_view.train_test_split(
    test_start=test_start
)
# Out:
# 2024-11-17 20:48:22,794 ERROR: INTERNAL Error: Assertion triggered in file "/usr/src/app/duckdb/src/execution/physical_plan/plan_asof_join.cpp" on line 43: asof_idx < op.conditions.size(). Detail: Python exception: FlyingDuckException. gRPC client debug context: UNKNOWN:Error received from peer ipv4:3.19.160.248:5005 {created_time:"2024-11-17T20:48:22.793874+01:00", grpc_status:2, grpc_message:"INTERNAL Error: Assertion triggered in file \"/usr/src/app/duckdb/src/execution/physical_plan/plan_asof_join.cpp\" on line 43: asof_idx < op.conditions.size(). Detail: Python exception: FlyingDuckException"}. Client context: IOError: Server never sent a data message. Detail: Internal
# Traceback (most recent call last):
#   File "/Users/filip/id2223-book/venv/lib/python3.11/site-packages/hsfs/core/arrow_flight_client.py", line 347, in afs_error_handler_wrapper
#     return func(instance, *args, **kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/filip/id2223-book/venv/lib/python3.11/site-packages/hsfs/core/arrow_flight_client.py", line 405, in read_query
#     return self._get_dataset(
#            ^^^^^^^^^^^^^^^^^^
#   File "/Users/filip/id2223-book/venv/lib/python3.11/site-packages/retrying.py", line 56, in wrapped_f
#     return Retrying(*dargs, **dkw).call(f, *args, **kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/filip/id2223-book/venv/lib/python3.11/site-packages/retrying.py", line 257, in call
#     return attempt.get(self._wrap_exception)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/filip/id2223-book/venv/lib/python3.11/site-packages/retrying.py", line 301, in get
#     six.reraise(self.value[0], self.value[1], self.value[2])
#   File "/Users/filip/id2223-book/venv/lib/python3.11/site-packages/six.py", line 719, in reraise
#     raise value
#   File "/Users/filip/id2223-book/venv/lib/python3.11/site-packages/retrying.py", line 251, in call
#     attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#                       ^^^^^^^^^^^^^^^^^^^
#   File "/Users/filip/id2223-book/venv/lib/python3.11/site-packages/hsfs/core/arrow_flight_client.py", line 396, in _get_dataset
#     reader = self._connection.do_get(info.endpoints[0].ticket, options)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "pyarrow/_flight.pyx", line 1633, in pyarrow._flight.FlightClient.do_get
#   File "pyarrow/_flight.pyx", line 58, in pyarrow._flight.check_flight_status
# pyarrow._flight.FlightServerError: INTERNAL Error: Assertion triggered in file "/usr/src/app/duckdb/src/execution/physical_plan/plan_asof_join.cpp" on line 43: asof_idx < op.conditions.size(). Detail: Python exception: FlyingDuckException. gRPC client debug context: UNKNOWN:Error received from peer ipv4:3.19.160.248:5005 {created_time:"2024-11-17T20:48:22.793874+01:00", grpc_status:2, grpc_message:"INTERNAL Error: Assertion triggered in file \"/usr/src/app/duckdb/src/execution/physical_plan/plan_asof_join.cpp\" on line 43: asof_idx < op.conditions.size(). Detail: Python exception: FlyingDuckException"}. Client context: IOError: Server never sent a data message. Detail: Internal
# Error: Reading data from Hopsworks, using Hopsworks Feature Query Service
# ---------------------------------------------------------------------------
# FlightServerError                         Traceback (most recent call last)
# File ~/id2223-book/venv/lib/python3.11/site-packages/hsfs/core/arrow_flight_client.py:347, in ArrowFlightClient._handle_afs_exception.<locals>.decorator.<locals>.afs_error_handler_wrapper(instance, *args, **kw)
#     346 try:
# --> 347     return func(instance, *args, **kw)
#     348 except Exception as e:
#
# File ~/id2223-book/venv/lib/python3.11/site-packages/hsfs/core/arrow_flight_client.py:405, in ArrowFlightClient.read_query(self, query_object, arrow_flight_config)
#     404 descriptor = pyarrow.flight.FlightDescriptor.for_command(query_encoded)
# --> 405 return self._get_dataset(
#     406     descriptor,
#     407     timeout=arrow_flight_config.get("timeout", self.timeout)
#     408     if arrow_flight_config
#     409     else self.timeout,
#     410 )
#
# File ~/id2223-book/venv/lib/python3.11/site-packages/retrying.py:56, in retry.<locals>.wrap.<locals>.wrapped_f(*args, **kw)
#      54 @six.wraps(f)
#      55 def wrapped_f(*args, **kw):
# ---> 56     return Retrying(*dargs, **dkw).call(f, *args, **kw)
#
# File ~/id2223-book/venv/lib/python3.11/site-packages/retrying.py:257, in Retrying.call(self, fn, *args, **kwargs)
#     256 if not self.should_reject(attempt):
# --> 257     return attempt.get(self._wrap_exception)
#     259 if self._after_attempts:
#
# File ~/id2223-book/venv/lib/python3.11/site-packages/retrying.py:301, in Attempt.get(self, wrap_exception)
#     300     else:
# --> 301         six.reraise(self.value[0], self.value[1], self.value[2])
#     302 else:
#
# File ~/id2223-book/venv/lib/python3.11/site-packages/six.py:719, in reraise(tp, value, tb)
#     718         raise value.with_traceback(tb)
# --> 719     raise value
#     720 finally:
#
# File ~/id2223-book/venv/lib/python3.11/site-packages/retrying.py:251, in Retrying.call(self, fn, *args, **kwargs)
#     250 try:
# --> 251     attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#     252 except:
#
# File ~/id2223-book/venv/lib/python3.11/site-packages/hsfs/core/arrow_flight_client.py:396, in ArrowFlightClient._get_dataset(self, descriptor, timeout)
#     395 options = pyarrow.flight.FlightCallOptions(timeout=timeout)
# --> 396 reader = self._connection.do_get(info.endpoints[0].ticket, options)
#     397 _logger.debug("Dataset fetched. Converting to dataframe.")
#
# File ~/id2223-book/venv/lib/python3.11/site-packages/pyarrow/_flight.pyx:1633, in pyarrow._flight.FlightClient.do_get()
#
# File ~/id2223-book/venv/lib/python3.11/site-packages/pyarrow/_flight.pyx:58, in pyarrow._flight.check_flight_status()
#
# FlightServerError: INTERNAL Error: Assertion triggered in file "/usr/src/app/duckdb/src/execution/physical_plan/plan_asof_join.cpp" on line 43: asof_idx < op.conditions.size(). Detail: Python exception: FlyingDuckException. gRPC client debug context: UNKNOWN:Error received from peer ipv4:3.19.160.248:5005 {created_time:"2024-11-17T20:48:22.793874+01:00", grpc_status:2, grpc_message:"INTERNAL Error: Assertion triggered in file \"/usr/src/app/duckdb/src/execution/physical_plan/plan_asof_join.cpp\" on line 43: asof_idx < op.conditions.size(). Detail: Python exception: FlyingDuckException"}. Client context: IOError: Server never sent a data message. Detail: Internal
#
# The above exception was the direct cause of the following exception:
#
# FeatureStoreException                     Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 X_train, X_test, y_train, y_test = feature_view.train_test_split(
#       2     test_start=test_start
#       3 )
#
# File ~/id2223-book/venv/lib/python3.11/site-packages/hsfs/usage.py:212, in method_logger.<locals>.wrapper(*args, **kwargs)
#     210 except Exception as e:
#     211     exception = e
# --> 212     raise e
#     213 finally:
#     214     try:
#
# File ~/id2223-book/venv/lib/python3.11/site-packages/hsfs/usage.py:208, in method_logger.<locals>.wrapper(*args, **kwargs)
#     205 exception = None
#     206 try:
#     207     # Call the original method
# --> 208     result = func(*args, **kwargs)
#     209     return result
#     210 except Exception as e:
#
# File ~/id2223-book/venv/lib/python3.11/site-packages/hsfs/feature_view.py:2394, in FeatureView.train_test_split(self, test_size, train_start, train_end, test_start, test_end, description, extra_filter, statistics_config, read_options, spine, primary_keys, event_time, training_helper_columns)
#    2372 self._validate_train_test_split(
#    2373     test_size=test_size, train_end=train_end, test_start=test_start
#    2374 )
#    2375 td = training_dataset.TrainingDataset(
#    2376     name=self.name,
#    2377     version=None,
#    (...)
#    2392     extra_filter=extra_filter,
#    2393 )
# -> 2394 td, df = self._feature_view_engine.get_training_data(
#    2395     self,
#    2396     read_options,
#    2397     training_dataset_obj=td,
#    2398     splits=[TrainingDatasetSplit.TRAIN, TrainingDatasetSplit.TEST],
#    2399     spine=spine,
#    2400     primary_keys=primary_keys,
#    2401     event_time=event_time,
#    2402     training_helper_columns=training_helper_columns,
#    2403 )
#    2404 warnings.warn(
#    2405     "Incremented version to `{}`.".format(td.version),
#    2406     util.VersionWarning,
#    2407 )
#    2408 return df
#
# File ~/id2223-book/venv/lib/python3.11/site-packages/hsfs/core/feature_view_engine.py:346, in FeatureViewEngine.get_training_data(self, feature_view_obj, read_options, splits, training_dataset_obj, training_dataset_version, spine, primary_keys, event_time, training_helper_columns)
#     333     self._check_feature_group_accessibility(feature_view_obj)
#     334     query = self.get_batch_query(
#     335         feature_view_obj,
#     336         training_dataset_version=td_updated.version,
#    (...)
#     344         spine=spine,
#     345     )
# --> 346     split_df = engine.get_instance().get_training_data(
#     347         td_updated, feature_view_obj, query, read_options
#     348     )
#     349     self.compute_training_dataset_statistics(
#     350         feature_view_obj, td_updated, split_df
#     351     )
#     353 # split df into features and labels df
#
# File ~/id2223-book/venv/lib/python3.11/site-packages/hsfs/engine/python.py:644, in Engine.get_training_data(self, training_dataset_obj, feature_view_obj, query_obj, read_options)
#     640 def get_training_data(
#     641     self, training_dataset_obj, feature_view_obj, query_obj, read_options
#     642 ):
#     643     if training_dataset_obj.splits:
# --> 644         return self._prepare_transform_split_df(
#     645             query_obj, training_dataset_obj, feature_view_obj, read_options
#     646         )
#     647     else:
#     648         df = query_obj.read(read_options=read_options)
#
# File ~/id2223-book/venv/lib/python3.11/site-packages/hsfs/engine/python.py:691, in Engine._prepare_transform_split_df(self, query_obj, training_dataset_obj, feature_view_obj, read_option)
#     683         result_dfs = self._time_series_split(
#     684             query_obj.read(read_options=read_option),
#     685             training_dataset_obj,
#     686             event_time,
#     687             drop_event_time=True,
#     688         )
#     689     else:
#     690         result_dfs = self._time_series_split(
# --> 691             query_obj.read(read_options=read_option),
#     692             training_dataset_obj,
#     693             event_time,
#     694         )
#     695 else:
#     696     result_dfs = self._random_split(
#     697         query_obj.read(read_options=read_option), training_dataset_obj
#     698     )
#
# File ~/id2223-book/venv/lib/python3.11/site-packages/hsfs/constructor/query.py:173, in Query.read(self, online, dataframe_type, read_options)
#     168     if len(self.joins) > 0 or None in [f.type for f in schema]:
#     169         raise ValueError(
#     170             "Pandas types casting only supported for feature_group.read()/query.select_all()"
#     171         )
# --> 173 return engine.get_instance().sql(
#     174     sql_query,
#     175     self._feature_store_name,
#     176     online_conn,
#     177     dataframe_type,
#     178     read_options,
#     179     schema,
#     180 )
#
# File ~/id2223-book/venv/lib/python3.11/site-packages/hsfs/engine/python.py:139, in Engine.sql(self, sql_query, feature_store, online_conn, dataframe_type, read_options, schema)
#     129 def sql(
#     130     self,
#     131     sql_query,
#    (...)
#     136     schema=None,
#     137 ):
#     138     if not online_conn:
# --> 139         return self._sql_offline(
#     140             sql_query,
#     141             feature_store,
#     142             dataframe_type,
#     143             schema,
#     144             hive_config=read_options.get("hive_config") if read_options else None,
#     145             arrow_flight_config=read_options.get("arrow_flight_config", {})
#     146             if read_options
#     147             else {},
#     148         )
#     149     else:
#     150         return self._jdbc(
#     151             sql_query, online_conn, dataframe_type, read_options, schema
#     152         )
#
# File ~/id2223-book/venv/lib/python3.11/site-packages/hsfs/engine/python.py:167, in Engine._sql_offline(self, sql_query, feature_store, dataframe_type, schema, hive_config, arrow_flight_config)
#     157 def _sql_offline(
#     158     self,
#     159     sql_query,
#    (...)
#     164     arrow_flight_config={},
#     165 ):
#     166     if isinstance(sql_query, dict) and "query_string" in sql_query:
# --> 167         result_df = util.run_with_loading_animation(
#     168             "Reading data from Hopsworks, using Hopsworks Feature Query Service",
#     169             arrow_flight_client.get_instance().read_query,
#     170             sql_query,
#     171             arrow_flight_config,
#     172         )
#     173     else:
#     174         with self._create_hive_connection(
#     175             feature_store, hive_config=hive_config
#     176         ) as hive_conn:
#     177             # Suppress SQLAlchemy pandas warning
#
# File ~/id2223-book/venv/lib/python3.11/site-packages/hsfs/util.py:426, in run_with_loading_animation(message, func, *args, **kwargs)
#     423 end = None
#     425 try:
# --> 426     result = func(*args, **kwargs)
#     427     end = time.time()
#     428     return result
#
# File ~/id2223-book/venv/lib/python3.11/site-packages/hsfs/core/arrow_flight_client.py:365, in ArrowFlightClient._handle_afs_exception.<locals>.decorator.<locals>.afs_error_handler_wrapper(instance, *args, **kw)
#     363     raise FeatureStoreException(str(e).split("Details:")[0]) from e
#     364 else:
# --> 365     raise FeatureStoreException(user_message) from e
#
# FeatureStoreException: Could not read data using Hopsworks Feature Query Service. If the issue persists, use read_options={"use_hive": True} instead.

# %%
X_train
# Out:
#      pm25_lag_1  pm25_lag_2  pm25_lag_3                       date  \
# 0          26.0        18.0        10.0  2022-09-03 00:00:00+00:00
# 1          10.0        26.0        18.0  2022-09-04 00:00:00+00:00
# 2          10.0        10.0        26.0  2022-09-05 00:00:00+00:00
# 3           8.0        10.0        10.0  2022-09-06 00:00:00+00:00
# 4          11.0         8.0        10.0  2022-09-07 00:00:00+00:00
# ..          ...         ...         ...                        ...
# 748        25.0        16.0        11.0  2024-10-10 00:00:00+00:00
# 749        16.0        25.0        16.0  2024-10-11 00:00:00+00:00
# 750        18.0        16.0        25.0  2024-10-12 00:00:00+00:00
# 751         5.0        18.0        16.0  2024-10-13 00:00:00+00:00
# 752        10.0         5.0        18.0  2024-10-14 00:00:00+00:00
#
#      temperature_2m_mean  precipitation_sum  wind_speed_10m_max  \
# 0              25.062500                0.0           32.475910
# 1              25.314585                0.0           35.452232
# 2              25.370832                0.0           38.166790
# 3              25.402079                0.0           34.653625
# 4              25.395830                0.0           28.512819
# ..                   ...                ...                 ...
# 748            26.962500                0.1           12.585848
# 749            26.974997                0.0           20.035059
# 750            27.570837                0.0           24.231236
# 751            27.718748                0.0           26.969982
# 752            27.154167                3.7           28.314978
#
#      wind_direction_10m_dominant    city
# 0                     209.555618  sweden
# 1                     215.710968  sweden
# 2                     215.488297  sweden
# 3                     217.330582  sweden
# 4                     215.725510  sweden
# ..                           ...     ...
# 748                   322.638031  sweden
# 749                   289.887482  sweden
# 750                   331.575836  sweden
# 751                     9.405353  sweden
# 752                    32.987946  sweden
#
# [753 rows x 9 columns]

# %%
X_test
# Out:
#      pm25_lag_1  pm25_lag_2  pm25_lag_3                       date  \
# 753        13.0        10.0         5.0  2024-10-15 00:00:00+00:00
# 754        15.0        13.0        10.0  2024-10-16 00:00:00+00:00
# 755        10.0        15.0        13.0  2024-10-17 00:00:00+00:00
# 756        12.0        10.0        15.0  2024-10-18 00:00:00+00:00
# 757        13.0        12.0        10.0  2024-10-19 00:00:00+00:00
# 758        33.0        13.0        12.0  2024-10-20 00:00:00+00:00
# 759        33.0        33.0        13.0  2024-10-21 00:00:00+00:00
# 760        44.0        33.0        33.0  2024-10-22 00:00:00+00:00
# 761        37.0        44.0        33.0  2024-10-23 00:00:00+00:00
# 762        24.0        37.0        44.0  2024-10-24 00:00:00+00:00
# 763        13.0        24.0        37.0  2024-10-25 00:00:00+00:00
# 764        17.0        13.0        24.0  2024-10-26 00:00:00+00:00
# 765        19.0        17.0        13.0  2024-10-27 00:00:00+00:00
# 766        30.0        19.0        17.0  2024-10-28 00:00:00+00:00
# 767         7.0        30.0        19.0  2024-10-29 00:00:00+00:00
# 768        16.0         7.0        30.0  2024-10-30 00:00:00+00:00
# 769        10.0        16.0         7.0  2024-10-31 00:00:00+00:00
# 770         6.0        10.0        16.0  2024-11-01 00:00:00+00:00
# 771         5.0         5.0         7.0  2024-11-05 00:00:00+00:00
# 772         7.0         5.0         5.0  2024-11-06 00:00:00+00:00
# 773        10.0         7.0         5.0  2024-11-07 00:00:00+00:00
# 774        13.0        10.0         7.0  2024-11-08 00:00:00+00:00
# 775        13.0        13.0        10.0  2024-11-09 00:00:00+00:00
# 776        13.0        13.0        13.0  2024-11-10 00:00:00+00:00
# 777        17.0        13.0        13.0  2024-11-11 00:00:00+00:00
# 778        10.0        17.0        13.0  2024-11-12 00:00:00+00:00
# 779        16.0        10.0        17.0  2024-11-13 00:00:00+00:00
# 780        13.0        16.0        10.0  2024-11-14 00:00:00+00:00
# 781        15.0        13.0        16.0  2024-11-15 00:00:00+00:00
# 782        18.0        15.0        13.0  2024-11-15 00:00:00+00:00
# 783         NaN         NaN         NaN  2024-11-17 00:00:00+00:00
#
#      temperature_2m_mean  precipitation_sum  wind_speed_10m_max  \
# 753            26.643751          33.099998           25.689600
# 754            27.262499           1.600000           25.558733
# 755            27.406250           0.100000           15.775434
# 756            27.658335           0.000000           13.104198
# 757            27.766665           0.000000           16.873980
# 758            27.804169           2.200000           26.248541
# 759            27.889585           0.300000           24.817818
# 760            27.993746           0.300000           24.179703
# 761            27.610418           0.600000           14.539945
# 762            27.877085           1.300000           22.640678
# 763            27.912500           0.000000           20.499462
# 764            27.875000           0.100000           19.434166
# 765            27.589584           0.000000           19.201874
# 766            27.681252           0.000000           18.061991
# 767            27.829165           0.000000           19.110542
# 768            27.368752           0.000000           16.873980
# 769            27.364586           0.000000           20.492352
# 770            28.068748           0.000000           23.667776
# 771            26.922918           0.000000           17.334290
# 772            28.020830           0.000000           20.707041
# 773            28.233332           0.200000           21.573734
# 774            27.487497           0.100000           19.240644
# 775            27.062500           0.000000           18.201374
# 776            27.693747           0.000000           23.588243
# 777            28.229170           0.000000           22.267679
# 778            27.387499           0.000000           14.707222
# 779            26.933329           0.000000           11.272657
# 780            27.133333           0.000000           22.543158
# 781            28.208338           0.000000           27.076691
# 782            28.208338           0.000000           27.076691
# 783            27.500000           0.000000           15.459054
#
#      wind_direction_10m_dominant    city
# 753                   182.575089  sweden
# 754                   182.273560  sweden
# 755                   134.102722  sweden
# 756                    10.451081  sweden
# 757                    12.371157  sweden
# 758                    46.137043  sweden
# 759                    92.540619  sweden
# 760                   126.484596  sweden
# 761                    80.708633  sweden
# 762                    67.683670  sweden
# 763                    66.702599  sweden
# 764                    63.037960  sweden
# 765                     6.402815  sweden
# 766                   279.695251  sweden
# 767                   238.384079  sweden
# 768                   210.016983  sweden
# 769                    49.937565  sweden
# 770                    52.651909  sweden
# 771                    69.187782  sweden
# 772                    74.156006  sweden
# 773                    62.836128  sweden
# 774                    49.684177  sweden
# 775                    53.724728  sweden
# 776                    56.494942  sweden
# 777                    49.503098  sweden
# 778                    32.287209  sweden
# 779                    63.180370  sweden
# 780                    65.626305  sweden
# 781                    51.594090  sweden
# 782                    51.594090  sweden
# 783                    27.758451  sweden

# %%
# Drop the index columns - 'date' (event_time) and 'city' (primary key)

train_features = X_train.drop(['date', 'city'], axis=1)
test_features = X_test.drop(['date', 'city'], axis=1)

# %%
y_train
# Out:
#      pm25
# 0    10.0
# 1    10.0
# 2     8.0
# 3    11.0
# 4    11.0
# ..    ...
# 748  16.0
# 749  18.0
# 750   5.0
# 751  10.0
# 752  13.0
#
# [753 rows x 1 columns]

# %% [markdown]
# The `Feature View` is now saved in Hopsworks and you can retrieve it using `FeatureStore.get_feature_view(name='...', version=1)`.

# %% [markdown]
# ---

# %% [markdown]
# ## <span style="color:#ff5f27;">🧬 Modeling</span>
#
# We will train a regression model to predict pm25 using our 4 features (wind_speed, wind_dir, temp, precipitation)

# %%
# Creating an instance of the XGBoost Regressor
xgb_regressor = XGBRegressor()

# Fitting the XGBoost Regressor to the training data
xgb_regressor.fit(train_features, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
# Predicting target values on the test set
y_pred = xgb_regressor.predict(test_features)

# Calculating Mean Squared Error (MSE) using sklearn
mse = mean_squared_error(y_test.iloc[:,0], y_pred)
print("MSE:", mse)

# Calculating R squared using sklearn
r2 = r2_score(y_test.iloc[:,0], y_pred)
print("R squared:", r2)
# Out:
# MSE: 61.378128
# R squared: 0.2793248585390017

# %%
df = y_test
df['predicted_pm25'] = y_pred

# %%
df['date'] = X_test['date']
df = df.sort_values(by=['date'])
df.tail(5)
# Out:
#      pm25  predicted_pm25                       date
# 779  13.0       12.075626  2024-11-13 00:00:00+00:00
# 780  15.0       14.382497  2024-11-14 00:00:00+00:00
# 781  18.0       17.249434  2024-11-15 00:00:00+00:00
# 782  19.0       25.312988  2024-11-15 00:00:00+00:00
# 783   7.0       28.586966  2024-11-17 00:00:00+00:00

# %%
# Creating a directory for the model artifacts if it doesn't exist
model_dir = "air_quality_model"
if not os.path.exists(model_dir):
    os.mkdir(model_dir)
images_dir = model_dir + "/images"
if not os.path.exists(images_dir):
    os.mkdir(images_dir)

# %%
file_path = images_dir + "/pm25_hindcast.png"
plt = util.plot_air_quality_forecast(city, street, df, file_path, hindcast=True) 
plt.show()
# Out:
# 2024-11-17 20:11:03,815 INFO: Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-11-17 20:11:03,817 INFO: Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-11-17 20:11:03,829 INFO: Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-11-17 20:11:03,830 INFO: Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %%
# Plotting feature importances using the plot_importance function from XGBoost
plot_importance(xgb_regressor, max_num_features=4)
feature_importance_path = images_dir + "/feature_importance.png"
plt.savefig(feature_importance_path)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## <span style='color:#ff5f27'>🗄 Model Registry</span>
#
# One of the features in Hopsworks is the model registry. This is where you can store different versions of models and compare their performance. Models from the registry can then be served as API endpoints.

# %% [markdown]
# ### <span style="color:#ff5f27;">⚙️ Model Schema</span>

# %% [markdown]
# The model needs to be set up with a [Model Schema](https://docs.hopsworks.ai/machine-learning-api/latest/generated/model_schema/), which describes the inputs and outputs for a model.
#
# A Model Schema can be automatically generated from training examples, as shown below.

# %%
from hsml.schema import Schema
from hsml.model_schema import ModelSchema

# Creating input and output schemas using the 'Schema' class for features (X) and target variable (y)
input_schema = Schema(X_train)
output_schema = Schema(y_train)

# Creating a model schema using 'ModelSchema' with the input and output schemas
model_schema = ModelSchema(input_schema=input_schema, output_schema=output_schema)

# Converting the model schema to a dictionary representation
schema_dict = model_schema.to_dict()

# %%
# Saving the XGBoost regressor object as a json file in the model directory
xgb_regressor.save_model(model_dir + "/model.json")

# %%
res_dict = { 
        "MSE": str(mse),
        "R squared": str(r2),
    }

# %%
mr = project.get_model_registry()

# Creating a Python model in the model registry named 'air_quality_xgboost_model'

aq_model = mr.python.create_model(
    name="air_quality_xgboost_model", 
    metrics= res_dict,
    model_schema=model_schema,
    input_example=X_test.sample().values, 
    description="Air Quality (PM2.5) predictor",
)

# Saving the model artifacts to the 'air_quality_model' directory in the model registry
aq_model.save(model_dir)
# Out:
# Connected. Call `.close()` to terminate connection gracefully.
#   0%|          | 0/6 [00:00<?, ?it/s]
# Uploading: 0.000%|          | 0/432532 elapsed<00:00 remaining<?
# Uploading: 0.000%|          | 0/19491 elapsed<00:00 remaining<?
# Uploading: 0.000%|          | 0/80615 elapsed<00:00 remaining<?
# Uploading: 0.000%|          | 0/139 elapsed<00:00 remaining<?
# Uploading: 0.000%|          | 0/864 elapsed<00:00 remaining<?
# Model created, explore it at https://c.app.hopsworks.ai:443/p/1158296/models/air_quality_xgboost_model/1
# Model(name: 'air_quality_xgboost_model', version: 1)

# %% [markdown]
# ---
# ## <span style="color:#ff5f27;">⏭️ **Next:** Part 04: Batch Inference</span>
#
# In the following notebook you will use your model for Batch Inference.
